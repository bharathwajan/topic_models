# %% [markdown]
# ![.](attachment:image.png) <br>
# Equation 1

# %%
import numpy as np
vecs=np.array([[1,2,4],[3,6,7],[2,3,4]]) 
exp=[3,5,2]
vecs.shape
# Out:
# (2, 3)

# %%
(((vecs[0]+vecs[1])/len(vecs))*exp)/len(exp)
# Out:
# array([2.        , 6.66666667, 3.66666667])

# %% [markdown]
# # Equation 2
# ![image.png](attachment:image.png)

# %%
# (vecs[0]+vecs[1])/len(vecs)
inner_sum =0
for vec,expe in zip(vecs,exp):
    inner_sum+=vec*expe
(inner_sum/len(vecs))/len(exp)
# Out:
# array([3.        , 6.        , 7.83333333])
